# %% [markdown]
# # **Car Prices Prediction**

# %% [markdown]
#   ## **Introduction**
#
#   The purpose of this project is to train and compare multiple regression models with the goal of predicting the price of used cars by knowing the following characteristics:
#
#   * **Manufacturer**;
#   * **Model**;
#   * **Year**;
#   * **Transmission**;
#   * **Mileage**;
#   * **Type of Fuel**;
#   * **Miles per Gallon**;
#   * **Engine Size**.
#
#   The dataset considered contains about 40000 examples of used cars sold in the UK, provided through the CVS file 'car_prices.csv'.
#
#   **N.B.:** The dataset is uploaded from Google Drive, so if you want to use the notebook you have to upload the dataset in advance.

# %% [markdown]
# ## **Libraries**
#
# Main libraries used are:
# * **tensorflow**: enables the development and training of machine learning models focused on DNN;
# * **keras**: used for semplify the training of the model;
# * **sklearn**: supports supervised and unsupervised learning, provides various tools for preprocessing, model selection, model evaluation and many other utilities;
# * **pandas**: Python library that provide data structures and functions to efficiently maanupulate data;
# * **numpy**: Python library that provide data structures and function to efficiently work on large N-dimensional numerical array;
# * **seaborn** and **matplotlib**: libraries used to visualize data and build graphs.

# %%
import tensorflow as tf
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.initializers import HeNormal, GlorotUniform
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error

from matplotlib import pyplot as plt

import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category = DeprecationWarning)

# %% [markdown]
# ## **Utils Function**

# %% [markdown]
# The following function is used to plot the metrics through epochs.

# %%
def plot_metrics(history):
    plt.figure(figsize=(14, 5))

    # Plot of loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    # Plot of MAE (Mean Absolute Error)
    plt.subplot(1, 2, 2)
    plt.plot(history.history['mean_absolute_error'], label='Training MAE')
    plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.title('Mean Absolute Error Over Epochs')
    plt.legend()

    plt.show()

# %% [markdown]
# This function is used to evaluate the performance on the testing set and generate the scatter plot to observe the performance.

# %%
def evaluate_performance(model, test_data, test_labels):
    loss, mae = model.evaluate(test_data, test_labels, verbose=0)
    print(f'Test Loss: {loss:.4f}')
    print(f'Test MAE: {mae:.4f}')

# %% [markdown]
# ## **Loading the Dataset**
#
# Load the dataset from Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
dataset_path = 'drive/MyDrive/projectML/car_prices.csv'
data = pd.read_csv(dataset_path)
#data.head()
# Out:
# Mounted at /content/drive

# %% [markdown]
# Once the dataset is loaded, the column for the prices to predict is removed.

# %%
#Dataset without price column
dataset = data.drop('price', axis = 1)
#dataset.head()

# %%
#The price column to predict
prices = data['price']
#prices.head()

# %% [markdown]
# ## **Dataset Preprocessing**
#
# Before the dataset can be used, the issue of missing values or NaN data must be considered so as to have "clean" data.

# %%
null_dataset = dataset.isnull().values.any()
null_prices = prices.isnull().values.any()

print('There are invalid entries inside the detaset.' if null_dataset else 'There are not invalid entries inside the dataset.')
print('There are invalid entries inside prices column.' if null_prices else 'There are not invalid entries inside prices column.')
# Out:
# There are not invalid entries inside the dataset.
# There are not invalid entries inside prices column.

# %% [markdown]
# Consider the unique values present within the features of the dataset.

# %%
manufacturer_unique_values = dataset['manufacturer'].unique()
model_unique_values = dataset['model'].unique()
transmission_unique_values = dataset['transmission'].unique()
type_of_fuel_unique_values = dataset['fuelType'].unique()

print("/---------------------------------------------------------------------------------------/\n")
print("Manufacturer Values:")
print(manufacturer_unique_values, "\n")
print("/---------------------------------------------------------------------------------------/\n")
print("Model Values:")
print(model_unique_values, "\n")
print("/---------------------------------------------------------------------------------------/\n")
print("Transmission Values:")
print(transmission_unique_values, "\n")
print("/---------------------------------------------------------------------------------------/\n")
print("Type of Fuel Values:")
print(type_of_fuel_unique_values, "\n")
print("/---------------------------------------------------------------------------------------/\n")
# Out:
# /---------------------------------------------------------------------------------------/
#
# Manufacturer Values:
# ['Audi' 'BMW' 'Toyota' 'Mercedes']
#
# /---------------------------------------------------------------------------------------/
#
# Model Values:
# [' A1' ' A6' ' A4' ' A3' ' Q3' ' Q5' ' A5' ' S4' ' Q2' ' A7' ' TT' ' Q7'
#  ' RS6' ' RS3' ' A8' ' Q8' ' RS4' ' RS5' ' R8' ' SQ5' ' S8' ' SQ7' ' S3'
#  ' S5' ' A2' ' RS7' ' 5 Series' ' 6 Series' ' 1 Series' ' 7 Series'
#  ' 2 Series' ' 4 Series' ' X3' ' 3 Series' ' X5' ' X4' ' i3' ' X1' ' M4'
#  ' X2' ' X6' ' 8 Series' ' Z4' ' X7' ' M5' ' i8' ' M2' ' M3' ' M6' ' Z3'
#  ' GT86' ' Corolla' ' RAV4' ' Yaris' ' Auris' ' Aygo' ' C-HR' ' Prius'
#  ' Avensis' ' Verso' ' Hilux' ' PROACE VERSO' ' Land Cruiser' ' Supra'
#  ' Camry' ' Verso-S' ' IQ' ' Urban Cruiser' ' SLK' ' S Class' ' SL CLASS'
#  ' G Class' ' GLE Class' ' GLA Class' ' A Class' ' B Class' ' GLC Class'
#  ' C Class' ' E Class' ' GL Class' ' CLS Class' ' CLC Class' ' CLA Class'
#  ' V Class' ' M Class' ' CL Class' ' GLS Class' ' GLB Class' ' X-CLASS'
#  '180' ' CLK' ' R Class' '230' '220' '200']
#
# /---------------------------------------------------------------------------------------/
#
# Transmission Values:
# ['Manual' 'Automatic' 'Semi-Auto' 'Other']
#
# /---------------------------------------------------------------------------------------/
#
# Type of Fuel Values:
# ['Petrol' 'Diesel' 'Hybrid' 'Other' 'Electric']
#
# /---------------------------------------------------------------------------------------/

# %% [markdown]
# The features of the dataset can be divided into two categories:
#
# * **categorical**: values that represent distinct and discrete attributes,  in our dataset we consider the following features as categorical: manufacturer, model, transmission, type of fuel;
# * **numerical**: values on which it is possible to do mathematical operations, in the dataset considered we consider the following features as numeric: year, milage, milage per gallon, engine size.

# %%
numerical_features = ['year', 'milage', 'mpg', 'engineSize']
categorical_features = ['manufacturer', 'model', 'transmission', 'fuelType']

# %% [markdown]
# Machine Learning and Deep Learning models require all inputs and outputs to be numerical values; we need to convert categorical features such that they are numerical, so we use the **Encoding One-Hot** technique.
#
# In this notebook we use sklearn's OneHotEncoder.

# %%
#Dataset with only categorical values
categorical_dataset = dataset[categorical_features]

#Inizialize the encoder
encoder = OneHotEncoder(handle_unknown = 'ignore', sparse = False)

#Transformation of categorical features
dataset_encoded = pd.DataFrame(encoder.fit_transform(categorical_dataset),
                               columns = encoder.get_feature_names_out(categorical_features))

#Update the dataset
dataset = pd.concat([dataset.drop(categorical_features, axis = 1), dataset_encoded], axis = 1)

dataset.describe()
# Out:
#                year        mileage           mpg    engineSize  \
# count  41306.000000   41306.000000  41306.000000  41306.000000
# mean    2017.099622   23766.754733     55.634063      1.962366
# std        2.247246   22627.617263     20.721036      0.602423
# min     1970.000000       1.000000      1.100000      0.000000
# 25%     2016.000000    6215.500000     45.600000      1.500000
# 50%     2017.000000   17467.500000     54.300000      2.000000
# 75%     2019.000000   34221.250000     64.200000      2.100000
# max     2020.000000  323000.000000    470.800000      6.600000
#
#        manufacturer_Audi  manufacturer_BMW  manufacturer_Mercedes  \
# count       41306.000000      41306.000000           41306.000000
# mean            0.258268          0.261003               0.317605
# std             0.437687          0.439187               0.465551
# min             0.000000          0.000000               0.000000
# 25%             0.000000          0.000000               0.000000
# 50%             0.000000          0.000000               0.000000
# 75%             1.000000          1.000000               1.000000
# max             1.000000          1.000000               1.000000
#
#        manufacturer_Toyota  model_ 1 Series  model_ 2 Series  ...  \
# count         41306.000000     41306.000000     41306.000000  ...
# mean              0.163124         0.047669         0.029754  ...
# std               0.369483         0.213067         0.169909  ...
# min               0.000000         0.000000         0.000000  ...
# 25%               0.000000         0.000000         0.000000  ...
# 50%               0.000000         0.000000         0.000000  ...
# 75%               0.000000         0.000000         0.000000  ...
# max               1.000000         1.000000         1.000000  ...
#
#           model_230  transmission_Automatic  transmission_Manual  \
# count  41306.000000            41306.000000         41306.000000
# mean       0.000024                0.333559             0.294533
# std        0.004920                0.471490             0.455838
# min        0.000000                0.000000             0.000000
# 25%        0.000000                0.000000             0.000000
# 50%        0.000000                0.000000             0.000000
# 75%        0.000000                1.000000             1.000000
# max        1.000000                1.000000             1.000000
#
#        transmission_Other  transmission_Semi-Auto  fuelType_Diesel  \
# count        41306.000000            41306.000000     41306.000000
# mean             0.000073                0.371835         0.539728
# std              0.008522                0.483300         0.498425
# min              0.000000                0.000000         0.000000
# 25%              0.000000                0.000000         0.000000
# 50%              0.000000                0.000000         1.000000
# 75%              0.000000                1.000000         1.000000
# max              1.000000                1.000000         1.000000
#
#        fuelType_Electric  fuelType_Hybrid  fuelType_Other  fuelType_Petrol
# count       41306.000000     41306.000000    41306.000000     41306.000000
# mean            0.000073         0.061541        0.003583         0.395076
# std             0.008522         0.240322        0.059752         0.488873
# min             0.000000         0.000000        0.000000         0.000000
# 25%             0.000000         0.000000        0.000000         0.000000
# 50%             0.000000         0.000000        0.000000         0.000000
# 75%             0.000000         0.000000        0.000000         1.000000
# max             1.000000         1.000000        1.000000         1.000000
#
# [8 rows x 112 columns]

# %% [markdown]
# Now we move on to the dataset splitting phase. To avoid data leakege problems and ensure accurate evaluation of model performance, we first split the data and then continue preprocessing on the training and traninig sets so that we have zero mean and unit variance.

# %%
dataset = dataset.iloc[:, :-1].values
prices = data.iloc[:, -1].values

#Split dataset in traning set and testing set
dataset_train, dataset_test, prices_train, prices_test = train_test_split(dataset,
                                                                          prices,
                                                                          test_size = 0.2,
                                                                          random_state = 0)

#Split training set in training and validation sets
dataset_training, dataset_validation, prices_training, prices_validation = train_test_split(dataset_train,
                                                                                            prices_train,
                                                                                            test_size = 0.2,
                                                                                            random_state = 0)

scaler = StandardScaler()

#Standardize data to zero mean and unit variance
dataset_training_scaled = scaler.fit_transform(dataset_training)
dataset_validation_scaled = scaler.transform(dataset_validation)
dataset_test_scaled = scaler.transform(dataset_test)

print("Train Size: ", len(dataset_training_scaled))
print("Validation Size: ", len(dataset_validation_scaled))
print("Test Size:", len(dataset_test_scaled))
# Out:
# Train Size:  26435
# Validation Size:  6609
# Test Size: 8262

# %% [markdown]
# ## **Neural Network**
#
# The first model we are going to consider is a neural network.
#
# Multiple versions were considered for the choice of hypermeters, including one version using Keras Tuner.
#
# The hyperparameters to be determined are:
# * **Weght Inizializer**;
# * **Number of Layers**;
# * **Number of Units in each Layer**;
# * **Learning Rate**.

# %% [markdown]
# It was decided to keep the number of levels, the number of units per level and the learning rate value fixed and then change the weight initializer and activation function.
# Specifically 5 levels, of which:
# * the input layer with 8 units, one per features;
# * the first hidden layer consisting of 50 units;
# * the second hidden layer consisting of 100 units;
# * the third hidden layer consisting of 50 units;
# * the output layer consisting of one unit, to predict the price of the car.

# %%
#Defined number of units per layer
number_of_layers = 3
units_per_layer = [50, 100, 50]

#Defined Learing Rate
learning_rate = 0.001

#Defined Weight Inizializer
initializer = HeNormal()

#Create Sequential Model
first_model = Sequential()

#Add level to model
for units in units_per_layer:
  first_model.add(Dense(units,
                        activation = 'relu',
                        kernel_initializer = initializer))


optimizer = Adam(learning_rate = learning_rate)
first_model.compile(optimizer = optimizer, loss = 'mean_squared_error', metrics = ['mean_absolute_error'])
first_model.build(input_shape = (None, 111))

# %%
first_model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_65 (Dense)            (None, 50)                5600
#
#  dense_66 (Dense)            (None, 100)               5100
#
#  dense_67 (Dense)            (None, 50)                5050
#
# =================================================================
# Total params: 15750 (61.52 KB)
# Trainable params: 15750 (61.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %%
history = first_model.fit(dataset_training_scaled,
                prices_training,
                epochs = 300,
                batch_size = 32,
                validation_data = (dataset_validation_scaled, prices_validation),
                callbacks = [early_stopping])
# Out:
# Epoch 1/300
# 827/827 [==============================] - 3s 3ms/step - loss: 325199328.0000 - mean_absolute_error: 13746.8877 - val_loss: 56849376.0000 - val_mean_absolute_error: 4600.2446
# Epoch 2/300
# 827/827 [==============================] - 2s 3ms/step - loss: 46274148.0000 - mean_absolute_error: 3738.0728 - val_loss: 38522008.0000 - val_mean_absolute_error: 3261.8218
# Epoch 3/300
# 827/827 [==============================] - 3s 4ms/step - loss: 37374756.0000 - mean_absolute_error: 3202.1975 - val_loss: 34617772.0000 - val_mean_absolute_error: 3038.1692
# Epoch 4/300
# 827/827 [==============================] - 2s 2ms/step - loss: 33820876.0000 - mean_absolute_error: 3023.1528 - val_loss: 32728648.0000 - val_mean_absolute_error: 2890.2039
# Epoch 5/300
# 827/827 [==============================] - 4s 4ms/step - loss: 31548838.0000 - mean_absolute_error: 2907.0908 - val_loss: 31504506.0000 - val_mean_absolute_error: 2816.3271
# Epoch 6/300
# 827/827 [==============================] - 4s 4ms/step - loss: 30000580.0000 - mean_absolute_error: 2826.1587 - val_loss: 30727100.0000 - val_mean_absolute_error: 2756.9888
# Epoch 7/300
# 827/827 [==============================] - 3s 3ms/step - loss: 28835304.0000 - mean_absolute_error: 2762.7563 - val_loss: 30154602.0000 - val_mean_absolute_error: 2734.7964
# Epoch 8/300
# 827/827 [==============================] - 2s 2ms/step - loss: 27945004.0000 - mean_absolute_error: 2710.6221 - val_loss: 29655486.0000 - val_mean_absolute_error: 2678.8809
# Epoch 9/300
# 827/827 [==============================] - 2s 2ms/step - loss: 27134292.0000 - mean_absolute_error: 2671.0408 - val_loss: 29218696.0000 - val_mean_absolute_error: 2633.1255
# Epoch 10/300
# 827/827 [==============================] - 2s 2ms/step - loss: 26418172.0000 - mean_absolute_error: 2627.6746 - val_loss: 28748850.0000 - val_mean_absolute_error: 2612.5430
# Epoch 11/300
# 827/827 [==============================] - 2s 2ms/step - loss: 25762786.0000 - mean_absolute_error: 2586.8677 - val_loss: 28469630.0000 - val_mean_absolute_error: 2616.9197
# Epoch 12/300
# 827/827 [==============================] - 3s 3ms/step - loss: 25281562.0000 - mean_absolute_error: 2556.9749 - val_loss: 28103984.0000 - val_mean_absolute_error: 2548.1343
# Epoch 13/300
# 827/827 [==============================] - 3s 4ms/step - loss: 24858886.0000 - mean_absolute_error: 2522.2170 - val_loss: 27776520.0000 - val_mean_absolute_error: 2561.0320
# Epoch 14/300
# 827/827 [==============================] - 2s 2ms/step - loss: 24544200.0000 - mean_absolute_error: 2502.6289 - val_loss: 27486172.0000 - val_mean_absolute_error: 2499.9246
# Epoch 15/300
# 827/827 [==============================] - 2s 2ms/step - loss: 24317874.0000 - mean_absolute_error: 2475.1101 - val_loss: 27346492.0000 - val_mean_absolute_error: 2483.9688
# Epoch 16/300
# 827/827 [==============================] - 2s 2ms/step - loss: 24096782.0000 - mean_absolute_error: 2460.8687 - val_loss: 27032730.0000 - val_mean_absolute_error: 2476.1045
# Epoch 17/300
# 827/827 [==============================] - 2s 2ms/step - loss: 23988100.0000 - mean_absolute_error: 2447.1667 - val_loss: 26915498.0000 - val_mean_absolute_error: 2458.9873
# Epoch 18/300
# 827/827 [==============================] - 2s 2ms/step - loss: 23807470.0000 - mean_absolute_error: 2434.4294 - val_loss: 26768804.0000 - val_mean_absolute_error: 2451.7932
# Epoch 19/300
# 827/827 [==============================] - 3s 4ms/step - loss: 23680174.0000 - mean_absolute_error: 2419.1204 - val_loss: 26620402.0000 - val_mean_absolute_error: 2438.7437
# Epoch 20/300
# 827/827 [==============================] - 3s 3ms/step - loss: 23527676.0000 - mean_absolute_error: 2405.1001 - val_loss: 26482374.0000 - val_mean_absolute_error: 2476.4014
# Epoch 21/300
# 827/827 [==============================] - 2s 2ms/step - loss: 23396938.0000 - mean_absolute_error: 2402.7451 - val_loss: 26232706.0000 - val_mean_absolute_error: 2412.9788
# Epoch 22/300
# 827/827 [==============================] - 3s 4ms/step - loss: 23321758.0000 - mean_absolute_error: 2387.8481 - val_loss: 26137396.0000 - val_mean_absolute_error: 2427.2617
# Epoch 23/300
# 827/827 [==============================] - 3s 4ms/step - loss: 23139268.0000 - mean_absolute_error: 2377.4783 - val_loss: 25960766.0000 - val_mean_absolute_error: 2424.7268
# Epoch 24/300
# 827/827 [==============================] - 6s 7ms/step - loss: 23090774.0000 - mean_absolute_error: 2375.4509 - val_loss: 25993348.0000 - val_mean_absolute_error: 2441.9846
# Epoch 25/300
# 827/827 [==============================] - 5s 6ms/step - loss: 23008752.0000 - mean_absolute_error: 2364.9260 - val_loss: 25709116.0000 - val_mean_absolute_error: 2396.2073
# Epoch 26/300
# 827/827 [==============================] - 4s 5ms/step - loss: 22886224.0000 - mean_absolute_error: 2356.0894 - val_loss: 25583236.0000 - val_mean_absolute_error: 2397.2139
# Epoch 27/300
# 827/827 [==============================] - 4s 5ms/step - loss: 22831652.0000 - mean_absolute_error: 2351.1128 - val_loss: 25484934.0000 - val_mean_absolute_error: 2388.1306
# Epoch 28/300
# 827/827 [==============================] - 6s 7ms/step - loss: 22720910.0000 - mean_absolute_error: 2341.6946 - val_loss: 25461778.0000 - val_mean_absolute_error: 2395.2559
# Epoch 29/300
# 827/827 [==============================] - 4s 5ms/step - loss: 22651424.0000 - mean_absolute_error: 2336.3232 - val_loss: 25305950.0000 - val_mean_absolute_error: 2361.7988
# Epoch 30/300
# 827/827 [==============================] - 4s 4ms/step - loss: 22576512.0000 - mean_absolute_error: 2326.5933 - val_loss: 25243638.0000 - val_mean_absolute_error: 2390.0874
# Epoch 31/300
# 827/827 [==============================] - 6s 7ms/step - loss: 22508406.0000 - mean_absolute_error: 2325.0989 - val_loss: 25175702.0000 - val_mean_absolute_error: 2371.8230
# Epoch 32/300
# 827/827 [==============================] - 4s 5ms/step - loss: 22407002.0000 - mean_absolute_error: 2318.7371 - val_loss: 25055268.0000 - val_mean_absolute_error: 2341.1292
# Epoch 33/300
# 827/827 [==============================] - 4s 4ms/step - loss: 22348172.0000 - mean_absolute_error: 2310.7288 - val_loss: 24971004.0000 - val_mean_absolute_error: 2345.9819
# Epoch 34/300
# 827/827 [==============================] - 4s 5ms/step - loss: 22283382.0000 - mean_absolute_error: 2306.1809 - val_loss: 24869920.0000 - val_mean_absolute_error: 2343.0649
# Epoch 35/300
# 827/827 [==============================] - 4s 5ms/step - loss: 22232984.0000 - mean_absolute_error: 2302.5479 - val_loss: 24883996.0000 - val_mean_absolute_error: 2335.6555
# Epoch 36/300
# 827/827 [==============================] - 2s 2ms/step - loss: 22172742.0000 - mean_absolute_error: 2295.5608 - val_loss: 24713052.0000 - val_mean_absolute_error: 2339.3831
# Epoch 37/300
# 827/827 [==============================] - 2s 2ms/step - loss: 22110486.0000 - mean_absolute_error: 2294.3721 - val_loss: 24614452.0000 - val_mean_absolute_error: 2321.5815
# Epoch 38/300
# 827/827 [==============================] - 2s 2ms/step - loss: 22044126.0000 - mean_absolute_error: 2284.2236 - val_loss: 24573520.0000 - val_mean_absolute_error: 2316.9819
# Epoch 39/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21948606.0000 - mean_absolute_error: 2281.2124 - val_loss: 24480626.0000 - val_mean_absolute_error: 2324.1494
# Epoch 40/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21915456.0000 - mean_absolute_error: 2271.9609 - val_loss: 24410874.0000 - val_mean_absolute_error: 2314.4683
# Epoch 41/300
# 827/827 [==============================] - 3s 4ms/step - loss: 21876034.0000 - mean_absolute_error: 2271.6162 - val_loss: 24338364.0000 - val_mean_absolute_error: 2306.5059
# Epoch 42/300
# 827/827 [==============================] - 3s 3ms/step - loss: 21805906.0000 - mean_absolute_error: 2266.3550 - val_loss: 24343932.0000 - val_mean_absolute_error: 2333.7925
# Epoch 43/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21760128.0000 - mean_absolute_error: 2265.8030 - val_loss: 24213400.0000 - val_mean_absolute_error: 2324.6787
# Epoch 44/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21714374.0000 - mean_absolute_error: 2260.1575 - val_loss: 24238442.0000 - val_mean_absolute_error: 2310.9817
# Epoch 45/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21670926.0000 - mean_absolute_error: 2256.4314 - val_loss: 24193196.0000 - val_mean_absolute_error: 2311.6006
# Epoch 46/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21664092.0000 - mean_absolute_error: 2259.7534 - val_loss: 24079926.0000 - val_mean_absolute_error: 2301.2522
# Epoch 47/300
# 827/827 [==============================] - 3s 3ms/step - loss: 21593406.0000 - mean_absolute_error: 2249.3811 - val_loss: 24125956.0000 - val_mean_absolute_error: 2322.0591
# Epoch 48/300
# 827/827 [==============================] - 3s 4ms/step - loss: 21568648.0000 - mean_absolute_error: 2246.9734 - val_loss: 24079894.0000 - val_mean_absolute_error: 2286.7583
# Epoch 49/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21537350.0000 - mean_absolute_error: 2243.4419 - val_loss: 23960398.0000 - val_mean_absolute_error: 2289.6277
# Epoch 50/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21506042.0000 - mean_absolute_error: 2241.0642 - val_loss: 23910086.0000 - val_mean_absolute_error: 2274.8342
# Epoch 51/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21446880.0000 - mean_absolute_error: 2239.3259 - val_loss: 23806190.0000 - val_mean_absolute_error: 2286.4761
# Epoch 52/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21427174.0000 - mean_absolute_error: 2236.6895 - val_loss: 23829520.0000 - val_mean_absolute_error: 2275.3037
# Epoch 53/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21410376.0000 - mean_absolute_error: 2232.9409 - val_loss: 23762196.0000 - val_mean_absolute_error: 2283.1753
# Epoch 54/300
# 827/827 [==============================] - 3s 4ms/step - loss: 21334620.0000 - mean_absolute_error: 2230.5083 - val_loss: 23690698.0000 - val_mean_absolute_error: 2270.9336
# Epoch 55/300
# 827/827 [==============================] - 3s 3ms/step - loss: 21334594.0000 - mean_absolute_error: 2231.1863 - val_loss: 23672858.0000 - val_mean_absolute_error: 2266.6445
# Epoch 56/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21283718.0000 - mean_absolute_error: 2225.5601 - val_loss: 23669040.0000 - val_mean_absolute_error: 2262.5415
# Epoch 57/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21259142.0000 - mean_absolute_error: 2224.3879 - val_loss: 23571452.0000 - val_mean_absolute_error: 2266.9985
# Epoch 58/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21250348.0000 - mean_absolute_error: 2221.2979 - val_loss: 23543966.0000 - val_mean_absolute_error: 2279.3601
# Epoch 59/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21216350.0000 - mean_absolute_error: 2220.0681 - val_loss: 23506742.0000 - val_mean_absolute_error: 2259.2126
# Epoch 60/300
# 827/827 [==============================] - 3s 3ms/step - loss: 21178224.0000 - mean_absolute_error: 2217.1831 - val_loss: 23507394.0000 - val_mean_absolute_error: 2247.0295
# Epoch 61/300
# 827/827 [==============================] - 3s 4ms/step - loss: 21142952.0000 - mean_absolute_error: 2218.4084 - val_loss: 23430330.0000 - val_mean_absolute_error: 2253.6775
# Epoch 62/300
# 827/827 [==============================] - 3s 4ms/step - loss: 21130246.0000 - mean_absolute_error: 2213.9912 - val_loss: 23439380.0000 - val_mean_absolute_error: 2249.1372
# Epoch 63/300
# 827/827 [==============================] - 2s 3ms/step - loss: 21118314.0000 - mean_absolute_error: 2214.0200 - val_loss: 23441392.0000 - val_mean_absolute_error: 2247.6738
# Epoch 64/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21084442.0000 - mean_absolute_error: 2212.1177 - val_loss: 23423084.0000 - val_mean_absolute_error: 2246.2327
# Epoch 65/300
# 827/827 [==============================] - 2s 2ms/step - loss: 21058748.0000 - mean_absolute_error: 2212.0801 - val_loss: 23382356.0000 - val_mean_absolute_error: 2266.2017
# Epoch 66/300
# 827/827 [==============================] - 3s 4ms/step - loss: 21017442.0000 - mean_absolute_error: 2206.6299 - val_loss: 23337426.0000 - val_mean_absolute_error: 2253.5300
# Epoch 67/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20999500.0000 - mean_absolute_error: 2206.7178 - val_loss: 23347478.0000 - val_mean_absolute_error: 2260.4116
# Epoch 68/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20988412.0000 - mean_absolute_error: 2204.9685 - val_loss: 23224174.0000 - val_mean_absolute_error: 2243.1021
# Epoch 69/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20959082.0000 - mean_absolute_error: 2203.0405 - val_loss: 23343018.0000 - val_mean_absolute_error: 2263.3181
# Epoch 70/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20952170.0000 - mean_absolute_error: 2203.8354 - val_loss: 23260632.0000 - val_mean_absolute_error: 2245.7014
# Epoch 71/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20921266.0000 - mean_absolute_error: 2199.4583 - val_loss: 23218032.0000 - val_mean_absolute_error: 2262.1848
# Epoch 72/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20942088.0000 - mean_absolute_error: 2202.3169 - val_loss: 23203442.0000 - val_mean_absolute_error: 2235.0964
# Epoch 73/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20874638.0000 - mean_absolute_error: 2194.8306 - val_loss: 23167048.0000 - val_mean_absolute_error: 2252.1619
# Epoch 74/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20868904.0000 - mean_absolute_error: 2194.2815 - val_loss: 23147218.0000 - val_mean_absolute_error: 2248.2744
# Epoch 75/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20840756.0000 - mean_absolute_error: 2192.9321 - val_loss: 23138076.0000 - val_mean_absolute_error: 2252.0591
# Epoch 76/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20811060.0000 - mean_absolute_error: 2189.3108 - val_loss: 23075214.0000 - val_mean_absolute_error: 2241.5205
# Epoch 77/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20789944.0000 - mean_absolute_error: 2189.9456 - val_loss: 23023584.0000 - val_mean_absolute_error: 2232.1746
# Epoch 78/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20805778.0000 - mean_absolute_error: 2191.2207 - val_loss: 23112122.0000 - val_mean_absolute_error: 2235.6365
# Epoch 79/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20773426.0000 - mean_absolute_error: 2187.2109 - val_loss: 23035212.0000 - val_mean_absolute_error: 2230.1162
# Epoch 80/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20757782.0000 - mean_absolute_error: 2187.0276 - val_loss: 23129686.0000 - val_mean_absolute_error: 2236.3088
# Epoch 81/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20744936.0000 - mean_absolute_error: 2186.6987 - val_loss: 23087826.0000 - val_mean_absolute_error: 2243.3142
# Epoch 82/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20693628.0000 - mean_absolute_error: 2182.4438 - val_loss: 22972280.0000 - val_mean_absolute_error: 2230.9597
# Epoch 83/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20713262.0000 - mean_absolute_error: 2183.8342 - val_loss: 22962432.0000 - val_mean_absolute_error: 2226.9775
# Epoch 84/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20675230.0000 - mean_absolute_error: 2182.1409 - val_loss: 22932788.0000 - val_mean_absolute_error: 2221.7393
# Epoch 85/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20669174.0000 - mean_absolute_error: 2180.8342 - val_loss: 22884846.0000 - val_mean_absolute_error: 2239.6809
# Epoch 86/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20635964.0000 - mean_absolute_error: 2179.7769 - val_loss: 22984412.0000 - val_mean_absolute_error: 2273.5295
# Epoch 87/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20617682.0000 - mean_absolute_error: 2179.1763 - val_loss: 22851176.0000 - val_mean_absolute_error: 2227.1394
# Epoch 88/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20586150.0000 - mean_absolute_error: 2178.4138 - val_loss: 22865814.0000 - val_mean_absolute_error: 2238.6096
# Epoch 89/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20608264.0000 - mean_absolute_error: 2180.3762 - val_loss: 22848870.0000 - val_mean_absolute_error: 2219.1116
# Epoch 90/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20559738.0000 - mean_absolute_error: 2173.9565 - val_loss: 22759838.0000 - val_mean_absolute_error: 2223.6318
# Epoch 91/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20552486.0000 - mean_absolute_error: 2173.6707 - val_loss: 22729842.0000 - val_mean_absolute_error: 2221.3337
# Epoch 92/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20551644.0000 - mean_absolute_error: 2172.9084 - val_loss: 22684084.0000 - val_mean_absolute_error: 2225.5144
# Epoch 93/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20538472.0000 - mean_absolute_error: 2173.8674 - val_loss: 22666106.0000 - val_mean_absolute_error: 2224.3850
# Epoch 94/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20506594.0000 - mean_absolute_error: 2170.1335 - val_loss: 22682508.0000 - val_mean_absolute_error: 2219.7112
# Epoch 95/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20479324.0000 - mean_absolute_error: 2167.6245 - val_loss: 22710014.0000 - val_mean_absolute_error: 2221.8491
# Epoch 96/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20463170.0000 - mean_absolute_error: 2168.2598 - val_loss: 22676064.0000 - val_mean_absolute_error: 2218.7480
# Epoch 97/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20480660.0000 - mean_absolute_error: 2171.0593 - val_loss: 22714454.0000 - val_mean_absolute_error: 2215.0667
# Epoch 98/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20470368.0000 - mean_absolute_error: 2167.9026 - val_loss: 22685472.0000 - val_mean_absolute_error: 2229.6982
# Epoch 99/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20450264.0000 - mean_absolute_error: 2167.4871 - val_loss: 22763714.0000 - val_mean_absolute_error: 2218.2979
# Epoch 100/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20434026.0000 - mean_absolute_error: 2165.8950 - val_loss: 22675480.0000 - val_mean_absolute_error: 2223.8433
# Epoch 101/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20430746.0000 - mean_absolute_error: 2167.8613 - val_loss: 22677638.0000 - val_mean_absolute_error: 2215.2395
# Epoch 102/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20391224.0000 - mean_absolute_error: 2164.5417 - val_loss: 22649604.0000 - val_mean_absolute_error: 2216.4841
# Epoch 103/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20410116.0000 - mean_absolute_error: 2163.0554 - val_loss: 22639224.0000 - val_mean_absolute_error: 2234.4080
# Epoch 104/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20362488.0000 - mean_absolute_error: 2163.4426 - val_loss: 22619866.0000 - val_mean_absolute_error: 2227.3127
# Epoch 105/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20339680.0000 - mean_absolute_error: 2161.8088 - val_loss: 22493424.0000 - val_mean_absolute_error: 2212.7002
# Epoch 106/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20356398.0000 - mean_absolute_error: 2161.1440 - val_loss: 22612970.0000 - val_mean_absolute_error: 2207.3953
# Epoch 107/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20311062.0000 - mean_absolute_error: 2158.7971 - val_loss: 22534192.0000 - val_mean_absolute_error: 2209.3027
# Epoch 108/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20315754.0000 - mean_absolute_error: 2157.8743 - val_loss: 22571308.0000 - val_mean_absolute_error: 2237.2405
# Epoch 109/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20294362.0000 - mean_absolute_error: 2159.5649 - val_loss: 22531332.0000 - val_mean_absolute_error: 2207.3743
# Epoch 110/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20301982.0000 - mean_absolute_error: 2156.3550 - val_loss: 22507764.0000 - val_mean_absolute_error: 2206.2659
# Epoch 111/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20281414.0000 - mean_absolute_error: 2153.7615 - val_loss: 22598588.0000 - val_mean_absolute_error: 2213.4409
# Epoch 112/300
# 827/827 [==============================] - 4s 4ms/step - loss: 20284570.0000 - mean_absolute_error: 2154.1440 - val_loss: 22391160.0000 - val_mean_absolute_error: 2203.6843
# Epoch 113/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20252034.0000 - mean_absolute_error: 2150.0405 - val_loss: 22556636.0000 - val_mean_absolute_error: 2211.0742
# Epoch 114/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20229320.0000 - mean_absolute_error: 2150.6633 - val_loss: 22453914.0000 - val_mean_absolute_error: 2222.2285
# Epoch 115/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20245658.0000 - mean_absolute_error: 2153.6184 - val_loss: 22509884.0000 - val_mean_absolute_error: 2227.8333
# Epoch 116/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20230716.0000 - mean_absolute_error: 2154.4626 - val_loss: 22442822.0000 - val_mean_absolute_error: 2206.6130
# Epoch 117/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20216740.0000 - mean_absolute_error: 2153.7639 - val_loss: 22428012.0000 - val_mean_absolute_error: 2197.1016
# Epoch 118/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20197152.0000 - mean_absolute_error: 2147.5049 - val_loss: 22378244.0000 - val_mean_absolute_error: 2205.6313
# Epoch 119/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20209044.0000 - mean_absolute_error: 2148.3567 - val_loss: 22414876.0000 - val_mean_absolute_error: 2214.3306
# Epoch 120/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20167778.0000 - mean_absolute_error: 2146.6423 - val_loss: 22390428.0000 - val_mean_absolute_error: 2218.3542
# Epoch 121/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20185432.0000 - mean_absolute_error: 2149.2795 - val_loss: 22358808.0000 - val_mean_absolute_error: 2209.7217
# Epoch 122/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20139816.0000 - mean_absolute_error: 2145.9941 - val_loss: 22329046.0000 - val_mean_absolute_error: 2198.9929
# Epoch 123/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20134564.0000 - mean_absolute_error: 2142.3684 - val_loss: 22300530.0000 - val_mean_absolute_error: 2205.8689
# Epoch 124/300
# 827/827 [==============================] - 2s 3ms/step - loss: 20112394.0000 - mean_absolute_error: 2145.0203 - val_loss: 22337498.0000 - val_mean_absolute_error: 2193.1934
# Epoch 125/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20135898.0000 - mean_absolute_error: 2145.1550 - val_loss: 22308056.0000 - val_mean_absolute_error: 2196.7146
# Epoch 126/300
# 827/827 [==============================] - 3s 3ms/step - loss: 20109226.0000 - mean_absolute_error: 2141.8372 - val_loss: 22332014.0000 - val_mean_absolute_error: 2186.8455
# Epoch 127/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20087168.0000 - mean_absolute_error: 2138.9128 - val_loss: 22253138.0000 - val_mean_absolute_error: 2194.3091
# Epoch 128/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20078820.0000 - mean_absolute_error: 2139.5938 - val_loss: 22247380.0000 - val_mean_absolute_error: 2191.5095
# Epoch 129/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20054778.0000 - mean_absolute_error: 2140.4885 - val_loss: 22412596.0000 - val_mean_absolute_error: 2192.3672
# Epoch 130/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20059864.0000 - mean_absolute_error: 2137.6306 - val_loss: 22270452.0000 - val_mean_absolute_error: 2198.2834
# Epoch 131/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20018436.0000 - mean_absolute_error: 2134.8743 - val_loss: 22400860.0000 - val_mean_absolute_error: 2215.6599
# Epoch 132/300
# 827/827 [==============================] - 3s 4ms/step - loss: 20036488.0000 - mean_absolute_error: 2136.7961 - val_loss: 22259430.0000 - val_mean_absolute_error: 2192.7402
# Epoch 133/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20027338.0000 - mean_absolute_error: 2133.3655 - val_loss: 22245284.0000 - val_mean_absolute_error: 2197.1633
# Epoch 134/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20002702.0000 - mean_absolute_error: 2136.1877 - val_loss: 22274316.0000 - val_mean_absolute_error: 2194.8499
# Epoch 135/300
# 827/827 [==============================] - 2s 2ms/step - loss: 20041122.0000 - mean_absolute_error: 2135.6794 - val_loss: 22258048.0000 - val_mean_absolute_error: 2206.6741
# Epoch 136/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19993328.0000 - mean_absolute_error: 2136.0911 - val_loss: 22224414.0000 - val_mean_absolute_error: 2194.0979
# Epoch 137/300
# 827/827 [==============================] - 2s 3ms/step - loss: 19979572.0000 - mean_absolute_error: 2133.5193 - val_loss: 22223306.0000 - val_mean_absolute_error: 2198.1848
# Epoch 138/300
# 827/827 [==============================] - 3s 4ms/step - loss: 19978704.0000 - mean_absolute_error: 2132.5549 - val_loss: 22206698.0000 - val_mean_absolute_error: 2182.4944
# Epoch 139/300
# 827/827 [==============================] - 2s 3ms/step - loss: 19961782.0000 - mean_absolute_error: 2130.5090 - val_loss: 22225274.0000 - val_mean_absolute_error: 2197.6926
# Epoch 140/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19955548.0000 - mean_absolute_error: 2130.1396 - val_loss: 22238220.0000 - val_mean_absolute_error: 2201.6890
# Epoch 141/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19945836.0000 - mean_absolute_error: 2130.0359 - val_loss: 22199088.0000 - val_mean_absolute_error: 2182.4226
# Epoch 142/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19939162.0000 - mean_absolute_error: 2130.8647 - val_loss: 22148788.0000 - val_mean_absolute_error: 2184.4478
# Epoch 143/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19918642.0000 - mean_absolute_error: 2129.5105 - val_loss: 22185830.0000 - val_mean_absolute_error: 2187.1562
# Epoch 144/300
# 827/827 [==============================] - 3s 4ms/step - loss: 19898946.0000 - mean_absolute_error: 2125.2073 - val_loss: 22144848.0000 - val_mean_absolute_error: 2200.7761
# Epoch 145/300
# 827/827 [==============================] - 3s 4ms/step - loss: 19933202.0000 - mean_absolute_error: 2132.4883 - val_loss: 22110110.0000 - val_mean_absolute_error: 2189.6799
# Epoch 146/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19893168.0000 - mean_absolute_error: 2124.5803 - val_loss: 22156240.0000 - val_mean_absolute_error: 2199.7932
# Epoch 147/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19871556.0000 - mean_absolute_error: 2127.4021 - val_loss: 22069800.0000 - val_mean_absolute_error: 2190.4792
# Epoch 148/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19920236.0000 - mean_absolute_error: 2128.5359 - val_loss: 21995346.0000 - val_mean_absolute_error: 2182.7793
# Epoch 149/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19873534.0000 - mean_absolute_error: 2123.3818 - val_loss: 22065994.0000 - val_mean_absolute_error: 2180.5378
# Epoch 150/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19865034.0000 - mean_absolute_error: 2125.1165 - val_loss: 22071702.0000 - val_mean_absolute_error: 2178.9292
# Epoch 151/300
# 827/827 [==============================] - 3s 3ms/step - loss: 19802786.0000 - mean_absolute_error: 2122.7478 - val_loss: 22227022.0000 - val_mean_absolute_error: 2208.1328
# Epoch 152/300
# 827/827 [==============================] - 3s 3ms/step - loss: 19843104.0000 - mean_absolute_error: 2122.6470 - val_loss: 22101570.0000 - val_mean_absolute_error: 2178.1780
# Epoch 153/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19830250.0000 - mean_absolute_error: 2120.9514 - val_loss: 22064132.0000 - val_mean_absolute_error: 2185.1299
# Epoch 154/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19846458.0000 - mean_absolute_error: 2121.6614 - val_loss: 22010058.0000 - val_mean_absolute_error: 2181.1609
# Epoch 155/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19812116.0000 - mean_absolute_error: 2123.1143 - val_loss: 22056566.0000 - val_mean_absolute_error: 2183.5881
# Epoch 156/300
# 827/827 [==============================] - 2s 2ms/step - loss: 19842368.0000 - mean_absolute_error: 2124.3921 - val_loss: 22066402.0000 - val_mean_absolute_error: 2184.9934
# Epoch 157/300
# 827/827 [==============================] - 3s 3ms/step - loss: 19830628.0000 - mean_absolute_error: 2121.8088 - val_loss: 22054456.0000 - val_mean_absolute_error: 2184.9360
# Epoch 158/300
# 827/827 [==============================] - 4s 4ms/step - loss: 19771370.0000 - mean_absolute_error: 2113.4744 - val_loss: 22030154.0000 - val_mean_absolute_error: 2177.4641

# %%
plot_metrics(history)

# %% [markdown]
# Let's test the neural network on the Test Set

# %%
evaluate_performance(first_model, dataset_test_scaled, prices_test)
# Out:
# Test Loss: 21130508.0000
# Test MAE: 2185.2361

# %%
first_model_predictions = first_model.predict(dataset_test).flatten()

print(f'Dimensioni di dataset_test_scaled: {dataset_test.shape}')
print(f'Dimensioni di prices_test: {prices_test.shape}')
print(f'Dimensione di first_model_predictions: {first_model_predictions.shape}')

print(first_model_predictions)


#first_model_mea = mean_absolute_error(prices_test.flatten(), first_model_predictions)
#printf(f'MEA on test set for the first model: {first_model_mea}')
# Out:
# 259/259 [==============================] - 1s 2ms/step
# Dimensioni di dataset_test_scaled: (8262, 111)
# Dimensioni di prices_test: (8262,)
# Dimensione di first_model_predictions: (413100,)
# [28931418. 28919850. 28940202. ... 21252998. 21250942. 21244814.]
